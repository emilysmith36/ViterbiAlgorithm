# %%
from IPython.display import HTML
shell = get_ipython()
def adjust_font_size():
  display(HTML('''<style>
      body{
          font-size: 16px;
      }
  '''))

if adjust_font_size not in shell.events.callbacks['pre_execute']:
  shell.events.register('pre_execute', adjust_font_size)

import random
import math

# %%
states=['Toxic','RedGreen','Blue']
aaOrder = list(substitution_matrix.keys())

eToxic = [0.042,0.023,0.045,0.015,0.042,0.015,0.038,0.045,0.038,0.023,0.019,0.034,0.038,0.064,0.057,0.098,0.072,0.095,0.106,0.129]
eRG = [0.051,0.051,0.064,0.025,0.076,0.032,0.032,0.044,0.032,0.057,0.07,0.057,0.051,0.032,0.038,0.032,0.076,0.07,0.045,0.045]
eB = [0.042,0.067,0.036,0.018,0.073,0.06,0.006,0.06,0.03,0.042,0.03,0.06,0.03,0.012,0.072,0.055,0.42,0.103,0.085,0.061]

gen1 = ['v','n','v','w','t','v','w','a','w','w','l','y','v','p','w','a','g','d','a','l','c','v','k','y','h','e','y','l','r','y','h','h','c','t','w','p','t','r','m','y','c','g','p','i','t','v','n','k','g','y','d','t','d','m','h','e','t','y','w','w','l','y','v','p','w','a','c','q','f','q','e','a','r','n','k','l','v','q','e','v','p','s','c','k','y','s','s','f','y','p','i','f','v','n','i','p','n','m','v','k','t','n','r','p','p','g','f','l','t','i','r','c','s','t','v','t','e','n','l','h','k','t','k','g','g','n','t','h']
gen2 = ['v','y','v','w','t','v','w','v','w','w','w','m','g','p','w','a','c','d','a','g','l','d','k','y','q','p','y','e','r','y','n','c','y','n','l','p','n','r','s','t','c','c','v','i','n','v','n','k','d','y','y','c','d','m','h','a','y','v','a','c','q','f','q','e','a','g','h','y','l','p','q','e','v','r','s','c','k','y','p','v','f','y','c','w','d','w','i','r','c','f','k','g','c','s','q','r','p','p','k','k','p','k','s','r','c','w','g','q','g','y','f','w','d','t','d','t','s','g','y','g','s','q']
gen3 = ['c','q','f','q','e','v','y','v','p','y','v','w','v','l','t','w','k','v','m','v','a','c','d','a','n','n','k','n','c','k','k','c','d','s','m','g','l','g','k','h','s','k','y','f','i','h','i','f','i','n','g','n','k','d','g','e','t','l','m','h','a','g','y','a','c','q','f','q','e','a','g','n','y','l','p','g','e','v','p','s','c','k','f','m','h','f','g','c','w','f','k','i','v','t','f','l','y','y','q','s','l','d','p','g','i','p','k','s','q','y','s','h','g','g','i','e','p','n','e','l','t','k','g','g','n','m','r']
gen4 = ['v','y','v','v','k','v','w','v','w','q','w','p','v','p','r','a','c','d','a','i','n','y','g','d','n','f','k','d','g','y','p','m','y','w','l','s','g','c','h','i','s','i','f','v','f','q','t','s','r','l','c','y','v','r','l','a','w','f','a','e','c','f','q','q','q','r','v','k','l','d','q','e','v','e','s','c','k','y','s','s','f','y','p','q','l','v','n','i','p','g','m','v','k','t','n','r','p','p','g','e','f','l','s','s','r','c','s','q','v','t','e','n','l','h','e','t','k','g','g','n','r','h']
    'd':{'a':2, 'c':1, 'd':3, 'e':1, 'f':-1,'g':0,'h':0,'i':0,'k':0,'l':-1,'m':-1,'n':-1,'p':0,'q':-1,'r':-1,'s':0,'t':0,'v':0,'w':-1,'y':0},
    'e':{'a':-3, 'c':-2, 'd':1, 'e':4,'f':3,'g':1,'h':1, 'i':1,'k':-1,'l':-2,'m':0,'n':0,'p':-2,'q':0,'r':0,'s':0,'t':-1,'v':-2,'w':0,'y':-1},
    'f':{'a':-4, 'c':0, 'd':2, 'e':-1,'f':0,'g':0,'h':-1,'i':1,'k':-2,'l':-1,'m':0,'n':-1,'p':0,'q':0,'r':1,'s':-1,'t':-1,'v':-1,'w':-1,'y':-1},
    'g':{'a':-4, 'c':0, 'd':0, 'e':1,'f':-1,'g':4,'h':-1,'i':0,'k':0,'l':0,'m':-1,'n':-1,'p':0,'q':-2,'r':-1,'s':1,'t':-1,'v':-1,'w':0,'y':-2},
    'h':{'a':-1, 'c':-1, 'd':0, 'e':1,'f':1,'g':-1,'h':4,'i':0,'k':0,'l':-1,'m':-1,'n':0,'p':-2,'q':0,'r':0,'s':0,'t':1,'v':-2,'w':-1,'y':0},
    'i':{'a':-4, 'c':-1, 'd':0, 'e':1,'f':-2,'g':0,'h':0,'i':4,'k':0,'l':-1,'m':1,'n':0,'p':0,'q':0,'r':-1,'s':0,'t':-1,'v':-2,'w':-1,'y':-1},
    'k':{'a':-3, 'c':1, 'd':0, 'e':-1,'f':-1,'g':0,'h':0,'i':0,'k':4,'l':-1,'m':-1,'n':-1,'p':0,'q':-1,'r':0,'s':-1,'t':1,'v':-1,'w':0,'y':1},
    'l':{'a':-4, 'c':1, 'd':-1,'e':-2,'f':0,'g':0,'h':-1,'i':-1,'k':-1,'l':5,'m':-1,'n':-1,'p':0,'q':1,'r':-1,'s':0,'t':-1,'v':-1,'w':-1,'y':0},
    'm':{'a':-3, 'c':0, 'd':-1, 'e':0,'f':-1,'g':-1,'h':-1,'i':1,'k':1,'l':-1,'m':4,'n':0,'p':-1,'q':0,'r':1,'s':-1,'t':-1,'v':-1,'w':0,'y':0},
    'n':{'a':0, 'c':-1, 'd':-1, 'e':0,'f':0,'g':-1,'h':0,'i':0,'k':-1,'l':-1,'m':0,'n':4,'p':1,'q':0,'r':0,'s':-1,'t':0,'v':0,'w':1,'y':-1},
    'p':{'a':-3, 'c':0, 'd':-1, 'e':-2,'f':0,'g':0,'h':-2,'i':0,'k':0,'l':0,'m':-1,'n':1,'p':4,'q':-1,'r':0,'s':0,'t':-2,'v':-1,'w':-1,'y':-1},
    'q':{'a':-3, 'c':-2, 'd':-1, 'e':0,'f':1,'g':-2,'h':0,'i':0,'k':-1,'l':1,'m':0,'n':0,'p':-1,'q':4,'r':-1,'s':-1,'t':0,'v':-2,'w':-1,'y':0},
    'r':{'a':-3,'c':-1, 'd':-1, 'e':0, 'f':-1,'g':-1,'h':0,'i':-1,'k':0,'l':-1,'m':1,'n':0,'p':0,'q':-1,'r':4,'s':0,'t':-1,'v':-1,'w':-1,'y':-1},
    's':{'a':-5, 'c':0, 'd':0, 'e':-0,'f':-1,'g':1,'h':0,'i':0,'k':-1,'l':0,'m':-1,'n':-1,'p':0,'q':-1,'r':0,'s':3,'t':0,'v':0,'w':0,'y':-1},
    't':{'a':1, 'c':-2, 'd':0, 'e':-1, 'f':-1,'g':-1,'h':1,'i':-1,'k':1,'l':-1,'m':-1,'n':0,'p':-2,'q':0,'r':-1,'s':0,'t':3,'v':-1,'w':-1,'y':0},
    'v':{'a':-1, 'c':1, 'd':0, 'e':-2,'f':-1,'g':-1,'h':-2,'i':-2,'k':-1,'l':-1,'m':-1,'n':0,'p':-1,'q':-2,'r':-1,'s':0,'t':-1,'v':4,'w':0,'y':-1},
    'w':{'a':-1, 'c':-2, 'd':-1,'e':0,'f':-1,'g':0,'h':-1,'i':-1,'k':0,'l':-1,'m':0,'n':0,'p':-1,'q':-1,'r':-1,'s':0,'t':-1,'v':0,'w':4,'y':-2},
    'y':{'a':-4, 'c':1, 'd':0,'e':0,'f':-1,'g':0,'h':0,'i':-1,'k':1,'l':0,'m':0,'n':-1,'p':-1,'q':0,'r':-1,'s':-1,'t':0,'v':-1,'w':-2,'y':4}
}

def logEmissionsDict(emi):
  if (len(emi) != len(aaOrder)):
    raise ValueError("emission list length does not match aa order length")
  return {aaOrder[i]: math.log(emi[i]) for i in range(len(aaOrder))}

def logEmissions(emi):
  return [math.log(e) for e in emi]

e = {
    'Toxic': logEmissionsDict(eToxic),
    'RedGreen': logEmissionsDict(eRG),
    'Blue': logEmissionsDict(eB)
}

transProbsLog = {
    'Toxic': {'Toxic': math.log(0.9), 'RedGreen': math.log(0.1), 'Blue':float('-inf')},
    'RedGreen': {'Toxic': float('-inf'), 'RedGreen': math.log(0.9), 'Blue':math.log(0.1)},
    'Blue': {'Toxic': math.log(0.1), 'RedGreen': float('-inf'), 'Blue':math.log(0.9)}
}

def viterbi(obs):
  V = [{}]
  path = {}

  for state in states:
    aa = obs[0]
    V[0][state] = initProbLog[state] + e[state].get(aa, float('-inf'))
    path[state] = [state]

  for t in range(1,len(obs)):
    V.append({})
    newPath = {}

    for curr in states:
      maxProb, prev = max(
          ((V[t-1][prev] + transProbsLog[prev][curr] + e[curr].get(obs[t], float('-inf')),prev)
          for prev in states if transProbsLog[prev][curr] != float('-inf')),
          key=lambda x: x[0]
      )
      V[t][curr] = maxProb
      newPath[curr] = path[prev] + [curr]

    path = newPath

  final = max(V[-1], key=lambda st:V[-1][st])
  return path[final]

viterbiGen1 = viterbi(gen1)
viterbiGen2 = viterbi(gen2)
viterbiGen3 = viterbi(gen3)
viterbiGen4 = viterbi(gen4)
viterbiGen5 = viterbi(gen5)
viterbiGen6 = viterbi(gen6)
viterbiGen7 = viterbi(gen7)
viterbiGen8 = viterbi(gen8)

print(viterbiGen1)
print("\n")
print(viterbiGen2)
print("\n")
print(viterbiGen3)
print("\n")
print(viterbiGen4)
print("\n")
print(viterbiGen5)
print("\n")
print(viterbiGen6)
print("\n")
print(viterbiGen7)
print("\n")
print(viterbiGen8)
# Out:
# <style>
#       body{
#           font-size: 16px;
#       }
# ...
